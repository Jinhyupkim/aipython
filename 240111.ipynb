# %% [markdown]
# <a href="https://colab.research.google.com/github/Jinhyupkim/aipython/blob/main/240111.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x =[1,2,3,4]
y =[1,4,9,16]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_excel('data1.xlsx')

plt.plot(df['kor'])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_excel('data1.xlsx')

plt.plot(df['kor'],'k--', marker='o', label='korean')
plt.plot(df['math'], marker='^', label='math')
plt.legend()
plt.show()

# marker기호, 색 문자 찾아보기

# %%
import matplotlib.pyplot as plt

x =[1,2,3,4]
y =[1,4,9,16]

plt.scatter(x,y)
plt.show()

# %%
# mission_1

import numpy as np
import matplotlib.pyplot as plt

x=np.arange(1,11)
y=np.random.randint(1,30,10)

plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,1,1,2,3,2,4]
plt.hist(x, bins=4, color='green', align='mid')
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[1,4,9,16,25]

fig, axs = plt.subplots(2,2)

axs[0,0].plot(x,y)
axs[0,1].scatter(x,y)
axs[1,0].bar(x,y)
axs[1,1].barh(x,y)
fig.suptitle('Drawing Graph')
plt.show()

# %%
#mission_2

import matplotlib.pyplot as plt
import pandas as pd

df=pd.read_excel('data1.xlsx')

plt.plot(df['name'],df['kor'],'g--', marker='o', label='국어점수')
plt.plot(df['name'],df['math'],'r', marker='^', label='수학점수')
plt.title('성적 그래프')
plt.xlabel('이름')
plt.ylabel('점수')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49457 (\N{HANGUL SYLLABLE SEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# []

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


#sepal = 꽃받침, petal = 꽃잎, setosa, versicolor, virginica
#평균: sepal_length    5.843333, sepal_width     3.057333, petal_length    3.758000, petal_width     1.199333

iris = pd.read_csv('iris.csv')

sns.scatterplot(x='petal_length',y='petal_width',hue='species',data=iris)
plt.title('Scatter Plot by seaborn', fontsize=20)
plt.show()

# %% [markdown]
# iris_data=sns.load_dataset('iris') 는 seaborn의 예시데이터 셋을 활용하는 것인데 seaborn에서 제공을 안해서 사용 x

# %%
import matplotlib.pyplot as plt
import seaborn as sns
iris = pd.read_csv('iris.csv')

sns.barplot(x='species', y='petal_length',data=iris, errorbar='sd')
plt.show()

sns.countplot(x='species',data=iris)
plt.show()

sns.pairplot(iris,hue='species')
plt.show()

sns.regplot(x='petal_length',y='petal_width',data=iris)
plt.show()

df=iris.corr()
sns.heatmap(data=df,annot=True,fmt='.2f',cbar=False)
plt.show()
# Out:
# <ipython-input-11-88330a360212>:17: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df=iris.corr()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

penguin=pd.read_csv('penguins.csv')

#1
sns.barplot(x='species', y='body_mass_g',data=penguin)

#2
sns.pairplot(penguin, hue='species')

# %%
#3
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

penguin=pd.read_csv('penguins.csv')

sns.regplot(x='body_mass_g',y='flipper_length_mm', data=penguin)
plt.show()
