# %% [markdown]
# <a href="https://colab.research.google.com/github/Jinhyupkim/aipython/blob/main/240110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
N = int(input())

a = [input( )for x in range(N)]

print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ba519a16e3bf> in <cell line: 1>()
# ----> 1 N = int(input())
#       2
#       3 a = [input( )for x in range(N)]
#       4
#       5 for b in a:
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
N = int(input())
file_list = [input() for _ in range(N)]

result = []

for file_name in file_list:
    if file_name.lower().endswith(('.png', '.jpg')):
        result.append(file_name)

print(result)

# %%
N = int(input())
file_list = [input() for _ in range(N)]

result = []

for file_name in file_list:
    name = file_name.split('.')


print(result)
# Out:
# 3
# gvvgvh.hhh
# bhbhbhbhb.kkkkk
# ghghg.hwp
# ['ghghg', 'hwp']

# %%
import pandas as pd

df = pd.DataFrame([['Kim',27,92],
                   ['Lee',33,98],
                   ['Park',19,87]])
print(df)
# Out:
#       0   1   2
# 0   Kim  27  92
# 1   Lee  33  98
# 2  Park  19  87

# %%
import pandas as pd
df = pd.DataFrame({'name':['Kim','Lee','Park'],
                   'age':[27,33,19],
                   'score':[92,98,87]})
print(df)
# Out:
#    name  age  score
# 0   Kim   27     92
# 1   Lee   33     98
# 2  Park   19     87

# %%
import pandas as pd

df = pd.read_csv('data.csv')
print(df)
# Out:
#    name   age   score
# 0   Kim    27      92
# 1   Lee    33      98
# 2  Park    19      87

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/lol.csv'
, delimiter='\t')
print(df)
# Out:
#            gameId   creationTime  gameDuration  seasonId  winner  firstBlood  \
# 0      3326086514  1504279457970          1949         9       1           2
# 1      3229566029  1497848803862          1851         9       1           1
# 2      3327363504  1504360103310          1493         9       1           2
# 3      3326856598  1504348503996          1758         9       1           1
# 4      3330080762  1504554410899          2094         9       1           2
# ...           ...            ...           ...       ...     ...         ...
# 51485  3308904636  1503076540231          1944         9       2           1
# 51486  3215685759  1496957179355          3304         9       2           1
# 51487  3322765040  1504029863961          2156         9       2           2
# 51488  3256675373  1499562036246          1475         9       2           2
# 51489  3317333020  1503612754059          1445         9       1           1
#
# ...

# %%
import pandas as pd

df = pd.read_excel('data.xlsx')
df.info() #결측치와 비결측치 확인

#non-null=비결측치
df['이름'][0:3]
df.loc[0:3,['이름']]
df.iloc[0:3,0:2] #내일 퀴즈
df['국어']>=80
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   반       10 non-null     object
#  1   이름      10 non-null     object
#  2   성별      10 non-null     object
#  3   국어      7 non-null      float64
#  4   수학      7 non-null      float64
#  5   응시여부    8 non-null      object
#  6   확인여부    7 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 688.0+ bytes
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9     True
# Name: 국어, dtype: bool

# %%
#ascending 오름차순

df.sort_values(by=['국어'], ascending=True)
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부
# 4  A반  하진희  여   0.0   85.0   응시  NaN
# 3  B반  김선후  남  33.0   44.0   응시  NaN
# 1  B반  김이정  여  78.0   45.0   응시   확인
# 7  B반  박서준  여  78.0   45.0   응시   확인
# 9  B반  이지서  여  86.0  100.0   응시   확인
# 0  A반  구이서  남  90.0   89.0   응시   확인
# 6  B반  김진솔  남  90.0   89.0   응시   확인
# 2  A반  오지수  남   NaN    NaN   응시   확인
# 5  A반  강현진  남   NaN    NaN  NaN  NaN
# 8  A반  김성희  남   NaN    NaN  NaN   확인

# %%
# 데이터프레임명.columns : 데이터프레임이 갖는 칼럼명들

print(list(df.columns))
# Out:
# ['반', '이름', '성별', '국어', '수학', '응시여부', '확인여부']

# %%
df.describe()
# Out:
#              국어          수학
# count   7.00000    7.000000
# mean   65.00000   71.000000
# std    34.82815   25.053277
# min     0.00000   44.000000
# 25%    55.50000   45.000000
# 50%    78.00000   85.000000
# 75%    88.00000   89.000000
# max    90.00000  100.000000

# %%
df.groupby('반').sum()
df.groupby('반').mean()
# Out:
# <ipython-input-51-2238d178af2b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('반').sum()
# <ipython-input-51-2238d178af2b>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('반').mean()
#       국어    수학
# 반
# A반  45.0  87.0
# B반  73.0  64.6

# %%
# 보통 원데이터 바꾸지 않고 새로 데이터를 만든다.
df['총점']=df['국어']+df['수학']
df
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부     총점
# 0  A반  구이서  남  90.0   89.0   응시   확인  179.0
# 1  B반  김이정  여  78.0   45.0   응시   확인  123.0
# 2  A반  오지수  남   NaN    NaN   응시   확인    NaN
# 3  B반  김선후  남  33.0   44.0   응시  NaN   77.0
# 4  A반  하진희  여   0.0   85.0   응시  NaN   85.0
# 5  A반  강현진  남   NaN    NaN  NaN  NaN    NaN
# 6  B반  김진솔  남  90.0   89.0   응시   확인  179.0
# 7  B반  박서준  여  78.0   45.0   응시   확인  123.0
# 8  A반  김성희  남   NaN    NaN  NaN   확인    NaN
# 9  B반  이지서  여  86.0  100.0   응시   확인  186.0

# %%
df.drop('확인여부',axis=1)
# Out:
#     반   이름 성별    국어     수학 응시여부     총점
# 0  A반  구이서  남  90.0   89.0   응시  179.0
# 1  B반  김이정  여  78.0   45.0   응시  123.0
# 2  A반  오지수  남   NaN    NaN   응시    NaN
# 3  B반  김선후  남  33.0   44.0   응시   77.0
# 4  A반  하진희  여   0.0   85.0   응시   85.0
# 5  A반  강현진  남   NaN    NaN  NaN    NaN
# 6  B반  김진솔  남  90.0   89.0   응시  179.0
# 7  B반  박서준  여  78.0   45.0   응시  123.0
# 8  A반  김성희  남   NaN    NaN  NaN    NaN
# 9  B반  이지서  여  86.0  100.0   응시  186.0

# %%
df.replace(0,7)
# Out:
#     반   이름 성별    국어     수학 응시여부 확인여부     총점
# 0  A반  구이서  남  90.0   89.0   응시   확인  179.0
# 1  B반  김이정  여  78.0   45.0   응시   확인  123.0
# 2  A반  오지수  남   NaN    NaN   응시   확인    NaN
# 3  B반  김선후  남  33.0   44.0   응시  NaN   77.0
# 4  A반  하진희  여   7.0   85.0   응시  NaN   85.0
# 5  A반  강현진  남   NaN    NaN  NaN  NaN    NaN
# 6  B반  김진솔  남  90.0   89.0   응시   확인  179.0
# 7  B반  박서준  여  78.0   45.0   응시   확인  123.0
# 8  A반  김성희  남   NaN    NaN  NaN   확인    NaN
# 9  B반  이지서  여  86.0  100.0   응시   확인  186.0

# %%
import pandas as pd

df1 = pd.read_excel('BoxOffice.xlsx')

#1.
df1

#2.
df1['대표국적'].value_counts()

#3.
df1[df1['대표국적'] == '영국']

#4.
df1.groupby('대표국적').min()
# Out:
# <ipython-input-66-99e0c577614b>:15: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   df1.groupby('대표국적').min()
#        순위        개봉일          매출액      관객수  스크린수   상영횟수  국적  \
# 대표국적
# 미국      5 2005-12-01  21476688172  3379762   319  38456  미국
# 영국    195 2013-12-05  25312684300  3449451   568  67267  영국
# 일본    172 2017-01-04  30628194346  3793790   947  88917  일본
# 한국      1 2005-01-27  22209675300  3389125   238  47155  한국
#
#                          배급사
# 대표국적
# 미국    (주)디스테이션,워너브러더스 코리아(주)
# 영국       유니버설픽쳐스인터내셔널 코리아(유)
# 일본             메가박스중앙(주)플러스엠
# 한국       (주)넥스트엔터테인먼트월드(NEW)
